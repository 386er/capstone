# %%
import numpy as np
import pickle
from pandas import DataFrame, read_csv
from sklearn import preprocessing
from sklearn import metrics as met
import warnings
import tensorflow as tf
from tensorflow.contrib import rnn
import helperModule as hm
import matplotlib.pyplot as plt
from tensorflow import nn
from matplotlib import gridspec


warnings.filterwarnings("ignore")
# %config InlineBackend.figure_format = 'retina'

# %%
#########################
############ Hyperparamter
#########################

st_dev = 0.2
learning_rate = 0.01
training_iters = 15000000
batch_size = 128
display_step = 100



n_input = 41 # Number of features
n_steps = 1 # timesteps
n_hidden = 128 # hidden layer num of nodes
n_classes = 5 # KDD99 total classes ( Normal + 4 attack types)

# %%
#########################
############ Read in data
#########################

data = pickle.load( open( "kdd99.p", "rb" ) )

x_train = data['x_train']
x_test = data['x_test']
y_train = data['y_train']
y_test = data['y_test']

# %%
tf.reset_default_graph()

# tf Graph input
x = tf.placeholder("float", [None, n_steps, n_input])
y = tf.placeholder("float", [None, n_classes])
#keep_prob = tf.placeholder(tf.float32, name='keep_prob')

# Define weights
W = {
    'out': tf.Variable(tf.truncated_normal([n_hidden, n_classes], stddev=st_dev))
}

b = {
    'out': tf.Variable(tf.zeros([n_classes]))
}

# %%
def RNN(x, W, b):

    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, n_steps, n_input)
    # Required shape: 'n_steps' tensors list of shape (batch_size, n_input)

    # Unstack to get a list of 'n_steps' tensors of shape (batch_size, n_input)
    x = tf.unstack(x, n_steps, 1)

    # Define a lstm cell with tensorflow
    lstm_cell = tf.contrib.rnn.LSTMCell(n_hidden, state_is_tuple = True)
        
    # Get lstm cell output
    output, states = tf.nn.static_rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(output[-1], W['out']) + b['out']

# %%
pred = RNN(x, W, b)

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

# Evaluate model
correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initializing the variables
init = tf.global_variables_initializer()

# %%
# Launch the graph
with tf.Session() as sess:
    sess.run(init)
    step = 1
    losses = {'train':[], 'validation':[]}
    # Keep training until reach max iterations
    while step * batch_size < training_iters:
        offset = (step * batch_size) % (y_train.shape[0] - batch_size)
        offset_test = (step * batch_size) % (y_test.shape[0] - batch_size)
        
        # Generate minibatches for training and validating.
        batch_x = x_train[offset:(offset + batch_size), :]
        batch_y = y_train[offset:(offset + batch_size), :]
        batch_test_x = x_test[offset_test:(offset_test + batch_size), :]
        batch_test_y = y_test[offset_test:(offset_test + batch_size), :]
        
        # Reshape data to feed into RNN
        batch_x = batch_x.reshape((batch_size, n_steps, n_input))
        batch_test_x = batch_test_x.reshape((batch_size, n_steps, n_input))
        
        # Run optimization op (backprop)
        sess.run(optimizer, feed_dict={x: batch_x, y: batch_y})
        loss = sess.run(cost, feed_dict={x: batch_x, y: batch_y})
        loss_test = sess.run(cost, feed_dict={x: batch_test_x, y: batch_test_y})

        if step % display_step == 0:

            print "Iter " + str(step*batch_size) + ", Minibatch Loss= " + "{:.6f}".format(loss) +  ", Minibatch Val Accuracy= " + \
                  "{:.6f}".format(loss)
                        
        losses['train'].append(loss)
        losses['validation'].append(loss_test)
        step += 1
            
    print("Optimization Finished!")

    # Generate confusion matrix for metrics computation
    y_pred = sess.run(tf.argmax(pred, 1), feed_dict={x:x_test.reshape((-1, n_steps, n_input)), keep_prob:1.0})
    y_true = np.argmax(y_test,1)
    conf_matrix = met.confusion_matrix(y_true, y_pred)
# Out:
# Iter 12800, Minibatch Loss= 0.965053, Minibatch Val Accuracy= 0.965053
# Iter 25600, Minibatch Loss= 0.010841, Minibatch Val Accuracy= 0.010841
# Iter 38400, Minibatch Loss= 0.001336, Minibatch Val Accuracy= 0.001336
# Iter 51200, Minibatch Loss= 0.340476, Minibatch Val Accuracy= 0.340476
# Iter 64000, Minibatch Loss= 0.000224, Minibatch Val Accuracy= 0.000224
# Iter 76800, Minibatch Loss= 0.058754, Minibatch Val Accuracy= 0.058754
# Iter 89600, Minibatch Loss= 0.020408, Minibatch Val Accuracy= 0.020408
# Iter 102400, Minibatch Loss= 0.000491, Minibatch Val Accuracy= 0.000491
# Iter 115200, Minibatch Loss= 0.000319, Minibatch Val Accuracy= 0.000319
# Iter 128000, Minibatch Loss= 0.000195, Minibatch Val Accuracy= 0.000195
# Iter 140800, Minibatch Loss= 0.021031, Minibatch Val Accuracy= 0.021031
# Iter 153600, Minibatch Loss= 0.001348, Minibatch Val Accuracy= 0.001348
# Iter 166400, Minibatch Loss= 0.000663, Minibatch Val Accuracy= 0.000663
# Iter 179200, Minibatch Loss= 0.000426, Minibatch Val Accuracy= 0.000426
# Iter 192000, Minibatch Loss= 0.000298, Minibatch Val Accuracy= 0.000298
# Iter 204800, Minibatch Loss= 0.000226, Minibatch Val Accuracy= 0.000226
# Iter 217600, Minibatch Loss= 0.000182, Minibatch Val Accuracy= 0.000182
# Iter 230400, Minibatch Loss= 0.000150, Minibatch Val Accuracy= 0.000150
# Iter 243200, Minibatch Loss= 0.000127, Minibatch Val Accuracy= 0.000127
# Iter 256000, Minibatch Loss= 0.000109, Minibatch Val Accuracy= 0.000109
# Iter 268800, Minibatch Loss= 0.000094, Minibatch Val Accuracy= 0.000094
# Iter 281600, Minibatch Loss= 0.000083, Minibatch Val Accuracy= 0.000083
# Iter 294400, Minibatch Loss= 0.000074, Minibatch Val Accuracy= 0.000074
# Iter 307200, Minibatch Loss= 0.000066, Minibatch Val Accuracy= 0.000066
# Iter 320000, Minibatch Loss= 0.000059, Minibatch Val Accuracy= 0.000059
# Iter 332800, Minibatch Loss= 0.000053, Minibatch Val Accuracy= 0.000053
# Iter 345600, Minibatch Loss= 0.058241, Minibatch Val Accuracy= 0.058241
# Iter 358400, Minibatch Loss= 0.000092, Minibatch Val Accuracy= 0.000092
# Iter 371200, Minibatch Loss= 0.008100, Minibatch Val Accuracy= 0.008100
# Iter 384000, Minibatch Loss= 0.000054, Minibatch Val Accuracy= 0.000054
# Iter 396800, Minibatch Loss= 0.013275, Minibatch Val Accuracy= 0.013275
# Iter 409600, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 422400, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 435200, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 448000, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 460800, Minibatch Loss= 0.000115, Minibatch Val Accuracy= 0.000115
# Iter 473600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 486400, Minibatch Loss= 0.002457, Minibatch Val Accuracy= 0.002457
# Iter 499200, Minibatch Loss= 0.000099, Minibatch Val Accuracy= 0.000099
# Iter 512000, Minibatch Loss= 0.000164, Minibatch Val Accuracy= 0.000164
# Iter 524800, Minibatch Loss= 0.000491, Minibatch Val Accuracy= 0.000491
# Iter 537600, Minibatch Loss= 0.026271, Minibatch Val Accuracy= 0.026271
# Iter 550400, Minibatch Loss= 0.002057, Minibatch Val Accuracy= 0.002057
# Iter 563200, Minibatch Loss= 0.000366, Minibatch Val Accuracy= 0.000366
# Iter 576000, Minibatch Loss= 0.009034, Minibatch Val Accuracy= 0.009034
# Iter 588800, Minibatch Loss= 0.001411, Minibatch Val Accuracy= 0.001411
# Iter 601600, Minibatch Loss= 0.002030, Minibatch Val Accuracy= 0.002030
# Iter 614400, Minibatch Loss= 0.000191, Minibatch Val Accuracy= 0.000191
# Iter 627200, Minibatch Loss= 0.000200, Minibatch Val Accuracy= 0.000200
# Iter 640000, Minibatch Loss= 0.028471, Minibatch Val Accuracy= 0.028471
# Iter 652800, Minibatch Loss= 0.004758, Minibatch Val Accuracy= 0.004758
# Iter 665600, Minibatch Loss= 0.000061, Minibatch Val Accuracy= 0.000061
# Iter 678400, Minibatch Loss= 0.013252, Minibatch Val Accuracy= 0.013252
# Iter 691200, Minibatch Loss= 0.000037, Minibatch Val Accuracy= 0.000037
# Iter 704000, Minibatch Loss= 0.000033, Minibatch Val Accuracy= 0.000033
# Iter 716800, Minibatch Loss= 0.000030, Minibatch Val Accuracy= 0.000030
# Iter 729600, Minibatch Loss= 0.000027, Minibatch Val Accuracy= 0.000027
# Iter 742400, Minibatch Loss= 0.000025, Minibatch Val Accuracy= 0.000025
# Iter 755200, Minibatch Loss= 0.000023, Minibatch Val Accuracy= 0.000023
# Iter 768000, Minibatch Loss= 0.000021, Minibatch Val Accuracy= 0.000021
# Iter 780800, Minibatch Loss= 0.000019, Minibatch Val Accuracy= 0.000019
# Iter 793600, Minibatch Loss= 0.000018, Minibatch Val Accuracy= 0.000018
# Iter 806400, Minibatch Loss= 0.000017, Minibatch Val Accuracy= 0.000017
# Iter 819200, Minibatch Loss= 0.000015, Minibatch Val Accuracy= 0.000015
# Iter 832000, Minibatch Loss= 0.000014, Minibatch Val Accuracy= 0.000014
# Iter 844800, Minibatch Loss= 0.000241, Minibatch Val Accuracy= 0.000241
# Iter 857600, Minibatch Loss= 0.000063, Minibatch Val Accuracy= 0.000063
# Iter 870400, Minibatch Loss= 0.000105, Minibatch Val Accuracy= 0.000105
# Iter 883200, Minibatch Loss= 0.000037, Minibatch Val Accuracy= 0.000037
# Iter 896000, Minibatch Loss= 0.000009, Minibatch Val Accuracy= 0.000009
# Iter 908800, Minibatch Loss= 0.000007, Minibatch Val Accuracy= 0.000007
# Iter 921600, Minibatch Loss= 0.000006, Minibatch Val Accuracy= 0.000006
# Iter 934400, Minibatch Loss= 0.000005, Minibatch Val Accuracy= 0.000005
# Iter 947200, Minibatch Loss= 0.000359, Minibatch Val Accuracy= 0.000359
# Iter 960000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 972800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 985600, Minibatch Loss= 0.030231, Minibatch Val Accuracy= 0.030231
# Iter 998400, Minibatch Loss= 0.000013, Minibatch Val Accuracy= 0.000013
# Iter 1011200, Minibatch Loss= 0.000124, Minibatch Val Accuracy= 0.000124
# Iter 1024000, Minibatch Loss= 0.000676, Minibatch Val Accuracy= 0.000676
# Iter 1036800, Minibatch Loss= 0.000085, Minibatch Val Accuracy= 0.000085
# Iter 1049600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1062400, Minibatch Loss= 0.202076, Minibatch Val Accuracy= 0.202076
# Iter 1075200, Minibatch Loss= 0.007160, Minibatch Val Accuracy= 0.007160
# Iter 1088000, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 1100800, Minibatch Loss= 0.000072, Minibatch Val Accuracy= 0.000072
# Iter 1113600, Minibatch Loss= 0.000019, Minibatch Val Accuracy= 0.000019
# Iter 1126400, Minibatch Loss= 0.049405, Minibatch Val Accuracy= 0.049405
# Iter 1139200, Minibatch Loss= 0.000010, Minibatch Val Accuracy= 0.000010
# Iter 1152000, Minibatch Loss= 0.000003, Minibatch Val Accuracy= 0.000003
# Iter 1164800, Minibatch Loss= 0.000003, Minibatch Val Accuracy= 0.000003
# Iter 1177600, Minibatch Loss= 0.000003, Minibatch Val Accuracy= 0.000003
# Iter 1190400, Minibatch Loss= 0.000003, Minibatch Val Accuracy= 0.000003
# Iter 1203200, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 1216000, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 1228800, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 1241600, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 1254400, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 1267200, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 1280000, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 1292800, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 1305600, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 1318400, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 1331200, Minibatch Loss= 0.008994, Minibatch Val Accuracy= 0.008994
# Iter 1344000, Minibatch Loss= 0.000019, Minibatch Val Accuracy= 0.000019
# Iter 1356800, Minibatch Loss= 0.000008, Minibatch Val Accuracy= 0.000008
# Iter 1369600, Minibatch Loss= 0.000103, Minibatch Val Accuracy= 0.000103
# Iter 1382400, Minibatch Loss= 0.000005, Minibatch Val Accuracy= 0.000005
# Iter 1395200, Minibatch Loss= 0.000004, Minibatch Val Accuracy= 0.000004
# Iter 1408000, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 1420800, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 1433600, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 1446400, Minibatch Loss= 0.097138, Minibatch Val Accuracy= 0.097138
# Iter 1459200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1472000, Minibatch Loss= 0.002066, Minibatch Val Accuracy= 0.002066
# Iter 1484800, Minibatch Loss= 0.000184, Minibatch Val Accuracy= 0.000184
# Iter 1497600, Minibatch Loss= 0.000201, Minibatch Val Accuracy= 0.000201
# Iter 1510400, Minibatch Loss= 0.000031, Minibatch Val Accuracy= 0.000031
# Iter 1523200, Minibatch Loss= 1.066413, Minibatch Val Accuracy= 1.066413
# Iter 1536000, Minibatch Loss= 0.000904, Minibatch Val Accuracy= 0.000904
# Iter 1548800, Minibatch Loss= 0.000007, Minibatch Val Accuracy= 0.000007
# Iter 1561600, Minibatch Loss= 0.006180, Minibatch Val Accuracy= 0.006180
# Iter 1574400, Minibatch Loss= 0.040607, Minibatch Val Accuracy= 0.040607
# Iter 1587200, Minibatch Loss= 0.000860, Minibatch Val Accuracy= 0.000860
# Iter 1600000, Minibatch Loss= 0.000025, Minibatch Val Accuracy= 0.000025
# Iter 1612800, Minibatch Loss= 0.000007, Minibatch Val Accuracy= 0.000007
# Iter 1625600, Minibatch Loss= 0.029842, Minibatch Val Accuracy= 0.029842
# Iter 1638400, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 1651200, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 1664000, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 1676800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1689600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1702400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1715200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1728000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1740800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1753600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1766400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1779200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1792000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1804800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1817600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1830400, Minibatch Loss= 0.002699, Minibatch Val Accuracy= 0.002699
# Iter 1843200, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 1856000, Minibatch Loss= 0.000006, Minibatch Val Accuracy= 0.000006
# Iter 1868800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1881600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1894400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1907200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1920000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1932800, Minibatch Loss= 0.000670, Minibatch Val Accuracy= 0.000670
# Iter 1945600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1958400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1971200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 1984000, Minibatch Loss= 0.000185, Minibatch Val Accuracy= 0.000185
# Iter 1996800, Minibatch Loss= 0.000265, Minibatch Val Accuracy= 0.000265
# Iter 2009600, Minibatch Loss= 0.000268, Minibatch Val Accuracy= 0.000268
# Iter 2022400, Minibatch Loss= 0.000249, Minibatch Val Accuracy= 0.000249
# Iter 2035200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2048000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2060800, Minibatch Loss= 0.004436, Minibatch Val Accuracy= 0.004436
# Iter 2073600, Minibatch Loss= 0.000120, Minibatch Val Accuracy= 0.000120
# Iter 2086400, Minibatch Loss= 0.000041, Minibatch Val Accuracy= 0.000041
# Iter 2099200, Minibatch Loss= 0.000004, Minibatch Val Accuracy= 0.000004
# Iter 2112000, Minibatch Loss= 0.221871, Minibatch Val Accuracy= 0.221871
# Iter 2124800, Minibatch Loss= 0.076756, Minibatch Val Accuracy= 0.076756
# Iter 2137600, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2150400, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2163200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2176000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2188800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2201600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2214400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2227200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2240000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2252800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2265600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2278400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2291200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2304000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2316800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2329600, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2342400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2355200, Minibatch Loss= 0.000005, Minibatch Val Accuracy= 0.000005
# Iter 2368000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2380800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2393600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2406400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2419200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2432000, Minibatch Loss= 0.000169, Minibatch Val Accuracy= 0.000169
# Iter 2444800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2457600, Minibatch Loss= 0.000138, Minibatch Val Accuracy= 0.000138
# Iter 2470400, Minibatch Loss= 0.004443, Minibatch Val Accuracy= 0.004443
# Iter 2483200, Minibatch Loss= 0.000383, Minibatch Val Accuracy= 0.000383
# Iter 2496000, Minibatch Loss= 0.067695, Minibatch Val Accuracy= 0.067695
# Iter 2508800, Minibatch Loss= 0.379039, Minibatch Val Accuracy= 0.379039
# Iter 2521600, Minibatch Loss= 0.209826, Minibatch Val Accuracy= 0.209826
# Iter 2534400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2547200, Minibatch Loss= 0.001172, Minibatch Val Accuracy= 0.001172
# Iter 2560000, Minibatch Loss= 0.000530, Minibatch Val Accuracy= 0.000530
# Iter 2572800, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2585600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2598400, Minibatch Loss= 0.038015, Minibatch Val Accuracy= 0.038015
# Iter 2611200, Minibatch Loss= 0.063818, Minibatch Val Accuracy= 0.063818
# Iter 2624000, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 2636800, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 2649600, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 2662400, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2675200, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2688000, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2700800, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2713600, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2726400, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2739200, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2752000, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2764800, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2777600, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2790400, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2803200, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2816000, Minibatch Loss= 0.026163, Minibatch Val Accuracy= 0.026163
# Iter 2828800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2841600, Minibatch Loss= 0.073025, Minibatch Val Accuracy= 0.073025
# Iter 2854400, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2867200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2880000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2892800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2905600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2918400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2931200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2944000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 2956800, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 2969600, Minibatch Loss= 0.000021, Minibatch Val Accuracy= 0.000021
# Iter 2982400, Minibatch Loss= 0.000036, Minibatch Val Accuracy= 0.000036
# Iter 2995200, Minibatch Loss= 0.004587, Minibatch Val Accuracy= 0.004587
# Iter 3008000, Minibatch Loss= 0.000008, Minibatch Val Accuracy= 0.000008
# Iter 3020800, Minibatch Loss= 0.000031, Minibatch Val Accuracy= 0.000031
# Iter 3033600, Minibatch Loss= 0.000004, Minibatch Val Accuracy= 0.000004
# Iter 3046400, Minibatch Loss= 0.000373, Minibatch Val Accuracy= 0.000373
# Iter 3059200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3072000, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 3084800, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 3097600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3110400, Minibatch Loss= 0.150880, Minibatch Val Accuracy= 0.150880
# Iter 3123200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3136000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3148800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3161600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3174400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3187200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3200000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3212800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3225600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3238400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3251200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3264000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3276800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3289600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3302400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3315200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3328000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3340800, Minibatch Loss= 0.000009, Minibatch Val Accuracy= 0.000009
# Iter 3353600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3366400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3379200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3392000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3404800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3417600, Minibatch Loss= 0.000131, Minibatch Val Accuracy= 0.000131
# Iter 3430400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3443200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3456000, Minibatch Loss= 0.000584, Minibatch Val Accuracy= 0.000584
# Iter 3468800, Minibatch Loss= 0.020556, Minibatch Val Accuracy= 0.020556
# Iter 3481600, Minibatch Loss= 0.000011, Minibatch Val Accuracy= 0.000011
# Iter 3494400, Minibatch Loss= 0.000014, Minibatch Val Accuracy= 0.000014
# Iter 3507200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3520000, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 3532800, Minibatch Loss= 0.008857, Minibatch Val Accuracy= 0.008857
# Iter 3545600, Minibatch Loss= 0.000385, Minibatch Val Accuracy= 0.000385
# Iter 3558400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3571200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3584000, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 3596800, Minibatch Loss= 0.005708, Minibatch Val Accuracy= 0.005708
# Iter 3609600, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 3622400, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 3635200, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 3648000, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 3660800, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 3673600, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 3686400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3699200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3712000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3724800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3737600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3750400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3763200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3776000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3788800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3801600, Minibatch Loss= 0.004129, Minibatch Val Accuracy= 0.004129
# Iter 3814400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3827200, Minibatch Loss= 0.004349, Minibatch Val Accuracy= 0.004349
# Iter 3840000, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 3852800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3865600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3878400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3891200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3904000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3916800, Minibatch Loss= 0.000440, Minibatch Val Accuracy= 0.000440
# Iter 3929600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 3942400, Minibatch Loss= 0.053072, Minibatch Val Accuracy= 0.053072
# Iter 3955200, Minibatch Loss= 0.022650, Minibatch Val Accuracy= 0.022650
# Iter 3968000, Minibatch Loss= 0.000009, Minibatch Val Accuracy= 0.000009
# Iter 3980800, Minibatch Loss= 0.000070, Minibatch Val Accuracy= 0.000070
# Iter 3993600, Minibatch Loss= 0.000144, Minibatch Val Accuracy= 0.000144
# Iter 4006400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4019200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4032000, Minibatch Loss= 0.000299, Minibatch Val Accuracy= 0.000299
# Iter 4044800, Minibatch Loss= 0.002917, Minibatch Val Accuracy= 0.002917
# Iter 4057600, Minibatch Loss= 0.000837, Minibatch Val Accuracy= 0.000837
# Iter 4070400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4083200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4096000, Minibatch Loss= 0.189992, Minibatch Val Accuracy= 0.189992
# Iter 4108800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4121600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4134400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4147200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4160000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4172800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4185600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4198400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4211200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4224000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4236800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4249600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4262400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4275200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4288000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4300800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4313600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4326400, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 4339200, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4352000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4364800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4377600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4390400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4403200, Minibatch Loss= 0.009269, Minibatch Val Accuracy= 0.009269
# Iter 4416000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4428800, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4441600, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4454400, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000
# Iter 4467200, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 4480000, Minibatch Loss= 0.000009, Minibatch Val Accuracy= 0.000009
# Iter 4492800, Minibatch Loss= 0.000001, Minibatch Val Accuracy= 0.000001
# Iter 4505600, Minibatch Loss= 0.000003, Minibatch Val Accuracy= 0.000003
# Iter 4518400, Minibatch Loss= 0.000002, Minibatch Val Accuracy= 0.000002
# Iter 4531200, Minibatch Loss= 0.007213, Minibatch Val Accuracy= 0.007213
# Iter 4544000, Minibatch Loss= 0.000000, Minibatch Val Accuracy= 0.000000

# %%
smoothed_loss = running_mean(losses['train'], 50)
smoothed_loss_train = running_mean(losses['validation'], 1800)

fig = plt.figure(figsize=(18,4))
gs  = gridspec.GridSpec(1, 2, height_ratios=[1],width_ratios=[0.5,0.5])
ax1 = plt.subplot(gs[0, 0:2])

ax1.plot(smoothed_loss, label='Training loss', color='crimson')
ax1.plot(smoothed_loss_train, label='Validation loss', color='teal')
ax1.legend()
plt.ylim([-0.2,3.5])
plt.show()

# %%
fig = plt.figure(figsize=(18,6))
gs  = gridspec.GridSpec(1, 2, height_ratios=[1],width_ratios=[0.5,0.5])
ax1 = plt.subplot(gs[0, 0:1])
ax2 = plt.subplot(gs[0, 1:])

ax1.plot(losses['train'], label='Training loss', color='crimson')
ax2.plot(losses['validation'], label='Validation loss', color='teal')
ax1.legend()
ax2.legend()

plt.show()

# %%
conf_bench = hm.getBenchmarkResults()
metrics = hm.computePerformanceMetrics(conf_bench, conf_matrix)
hm.plotMetrics(metrics)
